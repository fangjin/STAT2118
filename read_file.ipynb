# %%
data = read.csv("Iris.csv")

# %%
data1 = read.csv("C:/Users/Rachel/Documents/STAT1129-Code/Json/Sample.csv")

# %%
data1
# Out:
#   X1 Eldon.Base.for.stackable.storage.shelf..platinum   Muhammed.MacIntyre X3
# 1  2 1.7 Cubic Foot Compact "Cube" Office Refrigerators Barry French       293
# 2  3 Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   Barry French       293
# 3  4 R380                                               Clay Rozendal      483
# 4  5 Holmes HEPA Air Purifier                           Carlos Soltero     515
# 5  6 G.E. Longer-Life Indoor Recessed Floodlight Bulbs  Carlos Soltero     515
# 6  7 Angle-D Binders with Locking Rings, Label Holders  Carl Jackson       613
# 7  8 SAFCO Mobile Desk Side File, Wire Frame            Carl Jackson       613
# 8  9 SAFCO Commercial Wire Shelving, Black              Monica Federle     643
# 9 10 Xerox 198                                          Dorothy Badders    678
#   X.213.25 X38.94 X35   Nunavut Storage...Organization         X0.8
# 1  457.81  208.16 68.02 Nunavut Appliances                     0.58
# ...

# %%
data
# Out:
#     Id  SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm Species
# 1    1  5.1           3.5          1.4           0.2          Iris-setosa
# 2    2  4.9           3.0          1.4           0.2          Iris-setosa
# 3    3  4.7           3.2          1.3           0.2          Iris-setosa
# 4    4  4.6           3.1          1.5           0.2          Iris-setosa
# 5    5  5.0           3.6          1.4           0.2          Iris-setosa
# 6    6  5.4           3.9          1.7           0.4          Iris-setosa
# 7    7  4.6           3.4          1.4           0.3          Iris-setosa
# 8    8  5.0           3.4          1.5           0.2          Iris-setosa
# 9    9  4.4           2.9          1.4           0.2          Iris-setosa
# 10  10  4.9           3.1          1.5           0.1          Iris-setosa
# 11  11  5.4           3.7          1.5           0.2          Iris-setosa
# 12  12  4.8           3.4          1.6           0.2          Iris-setosa
# ...
